# %%
import os

import pandas as pd

# %%
INPUT_DIR = "/Users/willtrim/Desktop/RNAseq Bed Rest Data/outputs"

tpm_fp = os.path.join(INPUT_DIR, "kallisto.merged.transcript_tpm.tsv")

# %%
tpm = pd.read_csv(tpm_fp, sep="\t")
tpm
# Out:
#                        tx             gene_id  \
# 0       ENST00000373020.9  ENSG00000000003.16
# 1       ENST00000494424.1  ENSG00000000003.16
# 2       ENST00000496771.5  ENSG00000000003.16
# 3       ENST00000612152.4  ENSG00000000003.16
# 4       ENST00000373031.5   ENSG00000000005.6
# ...                   ...                 ...
# 385664  ENST00000409293.6   ENSG00000310576.1
# 385665  ENST00000485191.5   ENSG00000310576.1
# 385666  ENST00000585716.3   ENSG00000310576.1
# 385667  ENST00000590269.2   ENSG00000310576.1
# 385668  ENST00000850959.1   ENSG00000310577.1
#
#         SRR15503376_GSM5526409_A1_POST_Homo_sapiens_RNA.Seq  \
# 0                                               17.059900
# 1                                                3.228840
# 2                                                4.883210
# 3                                                0.000000
# 4                                               17.178200
# ...

# %%
subtmp = tpm.iloc[:,:3]

subtpm_fp = os.path.join(INPUT_DIR, "kallisto.merged.transcript_tpm.sub.tsv")

subtmp.to_csv(subtpm_fp, sep="\t", index=False)
